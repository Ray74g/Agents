# %% [markdown]
# # Git and Github

# %% [markdown]
# This guide is all about using source code control: Git and Github.
#
# By the end of this, you should be confident with every day code control processes, including fetching the latest code and submitting a PR to merge your own changes.

# %% [markdown]
# Here is Git and Github for a PC or Mac audience:
#
# Ask Chatgpt:
#
# I'm writing some self-study guides for students on my technical course. For context, the course involves working with python notebooks and python modules. Students might work in Python modules, or in ipynb notebooks. Students will typically work in Cursor. For package management, we're using uv. Students may be on Windows PC or Mac. Please develop a comprehensive tutorial to cover an introduction to Git and Github at a high level: Part 1: Explain what Git is, with its purpose and background Part 2: Basic Git commands - cover git add, git commit, git status, explaining how these work Part 3: Explain what Github is, and distinguish Github from Git, and give alternatives to Github Part 4: Explain why we run 'git clone' and exactly what it does Part 5: Explain git pull and git push (but note that there will be a separate guide to cover this in more detail for our repo). Include thorough explanations and exercises. Ensure this is good for a Windows PC and Mac audience.

# %% [markdown]
# ### If you'd like to become a Git pro
#
# If you want to go deep on using Git, here is a brilliant guide. Read this and you will know much more than me!
#
# https://beej.us/guide/bggit/
